# %%
#https://pythonprogramming.net/haar-cascade-face-eye-detection-python-opencv-tutorial/

# %%
import cv2
import matplotlib.pyplot as plt
import time
import os, os.path
import glob
from PIL import Image
import numpy as np
# %matplotlib inline

# %%
imgs = []

count =0

haar_eye = cv2.CascadeClassifier('/Users/lalida/anaconda3/lib/python3.6/site-packages/cv2/data/haarcascade_frontalface_alt.xml')

i =1
for filename in glob.glob('/Users/lalida/Thesis/photo/*.tiff'): #assuming tiff
    im = Image.open(filename)
    #imgs.append(im)
    test1 = cv2.imread(filename)
    gray = cv2.cvtColor(test1, cv2.COLOR_BGR2GRAY)
    eye_cascade = haar_eye.detectMultiScale(gray,scaleFactor = 1.1, minNeighbors = 5);
    print(i, ')','File name: ',filename.rstrip('.tiff').split('/')[-1],'Faces found: ',len(eye_cascade))

    if len(eye_cascade)==1:
        count = count+1
    i = i+1
    j = 1
    #for (x,y,w,h) in eye_cascade:
     #   cv2.rectangle(test1,(x,y),(x+w,y+h),(0,255,0),2)
      #  roi_color = test1[y:y + h, x:x + w]
       # plt.figure()
        #plt.imshow(roi_color)
       # plt.imshow(test1)
        #for i in range(len(eye_cascade)):
    for (x,y,w,h) in eye_cascade:
        cv2.rectangle(test1,(x,y),(x+w,y+h),(0,255,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = test1[y:y + h, x:x + w]
#         plt.imshow(test1)
        plt.imshow(roi_color)
        
        plt.gcf().savefig("/Users/lalida/Thesis/SegmentWholeH/" + filename.rstrip('.tiff').split('/')[-1] + "("+str(j)+")" + ".jpg")
        plt.clf()
        j=j+1
    
print(count)
# Out:
# 1 ) File name:  MK.AN3.127 Faces found:  1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3t/9zx7p7_x0sg3l62y_bp484ch0000gn/T/ipykernel_815/1947870372.py in <module>
#      32         plt.imshow(roi_color)
#      33
# ---> 34         plt.gcf().savefig("/Users/lalida/Thesis/SegmentWholeH/" + filename.rstrip('.tiff').split('/')[-1] + "("+str(j)+")" + ".jpg")
#      35         plt.clf()
#      36         j=j+1
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...
